# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvinChiew/MachineLearning/blob/main/Sklearn_Clustering_KMeans_illustration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as pl
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances

# %%
X, y = make_blobs(random_state=1)

# %%
# plot styles
_marker = {'marker':'o', 'lw':0.5, 'edgecolor':'k'}
_center = {'marker':'^', 'lw':1.0, 'edgecolor':'k', 'c':'y'}

# %%
fig, ax = pl.subplots(2, 4, figsize=(10, 5),
                      subplot_kw={'xticks': (), 'yticks': ()})
ax = ax.ravel()     # flatten axes(subplot pointer).

ax[0].set_title("Input data")
ax[0].scatter( X[:, 0], X[:, 1], **_marker, c='w')

ax[1].set_title("Initialization")
ax[1].scatter( X[:, 0], X[:, 1], **_marker, c='w')
init = X[:3, :]         # draw first three coordinates from X as initial point of centers
ax[1].scatter( init[:,0], init[:,1], **_center)

for i in range(1,4):    # illustrate prediciton for the first 3 steps
    centers = init if i == 1 else new_centers

    ax[i*2].set_title(f"Assign Points ({i})")
    km = KMeans(n_clusters=3, init=centers, max_iter=1, n_init=1).fit(X)       # one-step prediction
    labels = np.argmin(pairwise_distances(centers, X), axis=0)
    ax[i*2].scatter(X[:,0], X[:,1], c=labels, **_marker)
    ax[i*2].scatter( centers[:,0], centers[:,1], **_center)


    ax[i*2+1].set_title(f"Calculate Centers ({i})")
    new_centers = km.cluster_centers_       # coordinate the new 3 centers based on predicted values from KMean model
    ax[i*2+1].scatter(X[:,0], X[:,1], c=labels, **_marker)
    ax[i*2+1].scatter(new_centers[:,0],new_centers[:,1], **_center)
